# %% [markdown]
# # Solo per vedere il numero di dati per tag nel dataset

# %% [markdown]
# ### Librerie importate

# %%
##LIB FOR UTIL THING
import matplotlib.pyplot as plt 
import numpy as np
import re
##LIB FOR ML THING
import pandas as pd 
import scipy.stats as stats
import sklearn
from sklearn.model_selection import train_test_split
from sklearn.linear_model import LinearRegression
from sklearn.linear_model import LogisticRegression
from sklearn import datasets
from sklearn.cluster import KMeans
from sklearn.decomposition import PCA
import datetime as dt

# %%
def visualize_tag_title(df, tag):
    dt = df.loc[df["title"].str.contains(tag)]
    print("Numero righe presenti per il tag: ", tag, len(dt))
    plt.title("AI scatter plot")
    plt.scatter(dt["date"].values, dt["views"].values)

# %% [markdown]
# ### Codice per la visualizzazione dei dati

# %%
theme_list  = ["climate", "COVID", "health", "war", "AI", "like ", "love", "brain", "life", "science", "culture", "data", "music", "like" ]

for x in theme_list:
    visualize_tag_title(daTed, x)
# Out:
# Numero righe presenti per il tag:  climate 86
# Numero righe presenti per il tag:  COVID 20
# Numero righe presenti per il tag:  health 77
# Numero righe presenti per il tag:  war 77
# Numero righe presenti per il tag:  AI 41
# Numero righe presenti per il tag:  like  54
# Numero righe presenti per il tag:  love 58
# Numero righe presenti per il tag:  brain 88
# Numero righe presenti per il tag:  life 179
# Numero righe presenti per il tag:  science 63
# Numero righe presenti per il tag:  culture 19
# Numero righe presenti per il tag:  data 53
# Numero righe presenti per il tag:  music 48
# Numero righe presenti per il tag:  like 69

# %% [markdown]
# ### visualizzazione dei dati

# %%
daTed = pd.read_csv("data_ted.csv") # data_ted.csv")
